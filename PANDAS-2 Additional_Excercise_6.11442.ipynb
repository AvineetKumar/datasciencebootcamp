# %% [markdown]
# # PANDAS - 2 Additional_Excercise_6.11442

# %% [markdown]
# #### Get Data from the following link: http://files.grouplens.org/datasets/movielens/ml-20m.zip
# #### We will be using the following files for this exercise
#     #### ratings.csv : userId,movieId,rating, timestamp
#     #### tags.csv : userId,movieId, tag, timestamp
#     #### movies.csv : movieId, title, genres

# %% [markdown]
# #### 1. Read the dataset using pandas.

# %%
import pandas as pd

# %%
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')
movies = pd.read_csv('movies.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.info()
print()
tags.info()
print()
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000263 entries, 0 to 20000262
# Data columns (total 4 columns):
# userId       int64
# movieId      int64
# rating       float64
# timestamp    int64
# dtypes: float64(1), int64(3)
# memory usage: 610.4 MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465564 entries, 0 to 465563
# Data columns (total 4 columns):
# userId       465564 non-null int64
# movieId      465564 non-null int64
# tag          465548 non-null object
# timestamp    465564 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 14.2+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
# movieId    27278 non-null int64
# title      27278 non-null object
# genres     27278 non-null object
# dtypes: int64(1), object(2)
# memory usage: 639.4+ KB

# %% [markdown]
# #### 2. Extract the first row from tags and print its type.

# %%
tags.iloc[0]
# Out:
# userId                18
# movieId             4141
# tag          Mark Waters
# timestamp     1240597180
# Name: 0, dtype: object

# %% [markdown]
# ##### 3. Extract row 0, 11, 2000 from tags DataFrame.

# %%
tags.loc[[0,11,2000]]
# Out:
#       userId  movieId                tag   timestamp
# 0         18     4141        Mark Waters  1240597180
# 11        65     1783      noir thriller  1368149983
# 2000     910    68554  conspiracy theory  1368043943

# %% [markdown]
# #### 4. Print index, columns of the DataFrame.

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=27278, step=1)

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
ratings.index
# Out:
# RangeIndex(start=0, stop=20000263, step=1)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %% [markdown]
# #### 5. Calculate descriptive statistics for the 'ratings' column of the ratings DataFrame. Verify using describe().

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.groupby('rating').describe()
# Out:
#           movieId                                                           \
#             count          mean           std  min     25%     50%     75%
# rating
# 0.5      239125.0  13356.246729  23540.155879  1.0  1468.0  3552.0  7004.0
# 1.0      680732.0   5652.208219  14579.586860  1.0   704.0  2053.0  3688.0
# 1.5      279252.0  12377.773230  22686.931146  1.0  1405.0  3261.0  6629.0
# 2.0     1430997.0   6733.595232  16488.702470  1.0   783.0  2143.0  3916.0
# 2.5      883398.0  13669.268192  24030.549420  1.0  1500.0  3499.0  7036.0
# 3.0     4291193.0   6770.763264  17060.805484  1.0   548.0  1735.0  3704.0
# 3.5     2200156.0  14814.098703  24964.575966  1.0  1479.0  3624.0  7502.0
# 4.0     5561926.0   8342.514461  18921.333278  1.0   904.0  2054.0  4232.0
# 4.5     1534824.0  14585.414824  24569.051130  1.0  1252.0  3448.0  7502.0
# 5.0     2898660.0   6275.356017  16245.763837  1.0   662.0  1321.0  3275.0
#
# ...

# %% [markdown]
# #### 6. Filter out ratings with rating > 5

# %%
ratings[ratings['rating']>5]
# 5 is the maximum rating and there are no values in dataframe having rating greater then 5, hence output return nothing
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %% [markdown]
# #### 7. Find how many null values, missing values are present. Deal with them. Print out how many rows have been modified.

# %%
movies.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
# finding NaN value at dataframe
tags.isnull().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
#checking NaN value at column level
tags[tags['tag'].isnull()]
# Out:
#         userId  movieId  tag   timestamp
# 373276  116460      123  NaN  1199450867
# 373277  116460      346  NaN  1199451946
# 373281  116460     1184  NaN  1199452261
# 373288  116460     1785  NaN  1199452006
# 373289  116460     2194  NaN  1199450677
# 373291  116460     2691  NaN  1199451002
# 373299  116460     4103  NaN  1199451920
# 373301  116460     4473  NaN  1199451040
# 373303  116460     4616  NaN  1199452441
# 373319  116460     7624  NaN  1199452266
# 373325  116460     8898  NaN  1199450757
# 373332  116460    32460  NaN  1199450901
# 373334  116460    33826  NaN  1199450703
# 373339  116460    36537  NaN  1199450736
# 373340  116460    55805  NaN  1199450941
# 454615  133634    33826  NaN  1221450908

# %%
#axis 1 = column axis 0 = row
tags.fillna(value='Not Provided',axis=0,inplace=True)

# %%
tags.isnull().sum()
# Out:
# userId       0
# movieId      0
# tag          0
# timestamp    0
# dtype: int64

# %% [markdown]
# #### 8. Filter out movies from the movies DataFrame that are of type 'Animation'.

# %%
movies[movies['genres'] == 'Animation']
# Out:
#        movieId                                              title     genres
# 2503      2588                                   Cloudland (1998)  Animation
# 4906      5002                               Fritz the Cat (1972)  Animation
# 4907      5003            Nine Lives of Fritz the Cat, The (1974)  Animation
# 9455     27738                    Cathedral, The (Katedra) (2002)  Animation
# 9989     32840                                     Vincent (1982)  Animation
# 13444    66335                  Afro Samurai: Resurrection (2009)  Animation
# 13858    69469                        Garfield's Pet Force (2009)  Animation
# 14184    71158                Immigrants (L.A. Dolce Vita) (2008)  Animation
# 14492    72603                            Merry Madagascar (2009)  Animation
# 14578    72927                                 Donkey Xote (2007)  Animation
# 14580    72931                                       Tango (1981)  Animation
# ...

# %% [markdown]
# #### 9. Find the average rating of movies.

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %% [markdown]
# #### 10. Perform an inner join of movies and tags based on movieId.

# %%
movies.join(tags,on=['movieId'],how='inner',lsuffix='_movies',rsuffix='_tags')
# Out:
#        movieId  movieId_movies  \
# 0            1               1
# 1            2               2
# 2            3               3
# 3            4               4
# 4            5               5
# 5            6               6
# 6            7               7
# 7            8               8
# 8            9               9
# 9           10              10
# 10          11              11
# 11          12              12
# 12          13              13
# 13          14              14
# 14          15              15
# 15          16              16
# 16          17              17
# 17          18              18
# 18          19              19
# 19          20              20
# 20          21              21
# 21          22              22
# 22          23              23
# 23          24              24
# 24          25              25
# 25          26              26
# 26          27              27
# 27          28              28
# 28          29              29
# ...

# %% [markdown]
# #### Print out the 5 movies that belong to the Comedy genre and have rating greater than 4.

# %%
movietagrating = pd.concat([movies,tags,ratings],axis=1,join='inner')
movietagrating[(movietagrating['genres']=='Comedy') & (movietagrating['rating'] > 4)]['title'][:5]
# Out:
# 142                        Brothers McMullen, The (1995)
# 185                                    Party Girl (1995)
# 201    To Wong Foo, Thanks for Everything! Julie Newm...
# 220                                        Clerks (1994)
# 231                                  Exit to Eden (1994)
# Name: title, dtype: object

# %% [markdown]
# #### 12. Split 'genres' into multiple columns.

# %%
movies['genres'].str.split("|", n=4,expand = True)
# Out:
#                         0          1         2        3         4
# 0               Adventure  Animation  Children   Comedy   Fantasy
# 1               Adventure   Children   Fantasy     None      None
# 2                  Comedy    Romance      None     None      None
# 3                  Comedy      Drama   Romance     None      None
# 4                  Comedy       None      None     None      None
# 5                  Action      Crime  Thriller     None      None
# 6                  Comedy    Romance      None     None      None
# 7               Adventure   Children      None     None      None
# 8                  Action       None      None     None      None
# 9                  Action  Adventure  Thriller     None      None
# 10                 Comedy      Drama   Romance     None      None
# 11                 Comedy     Horror      None     None      None
# 12              Adventure  Animation  Children     None      None
# ...

# %% [markdown]
# #### 13. Extract year from title e.g. (1995).

# %%
def extractyear(string):
    year=''
    for char in string:
        if char.isdigit():
            year=year+char
    return year

movies['year']=movies['title'].apply(extractyear)
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %% [markdown]
# #### 14. Select rows based on timestamps later than 2015-02-01.

# %%
tags['date'] = pd.to_datetime(tags['timestamp'])

# %%
tags[tags['date']<'2015-02-01']
# Out:
#         userId  movieId                                                tag  \
# 0           18     4141                                        Mark Waters
# 1           65      208                                          dark hero
# 2           65      353                                          dark hero
# 3           65      521                                      noir thriller
# 4           65      592                                          dark hero
# 5           65      668                                          bollywood
# 6           65      898                                   screwball comedy
# 7           65     1248                                      noir thriller
# 8           65     1391                                               mars
# 9           65     1617                                           neo-noir
# 10          65     1694                                              jesus
# ...

# %% [markdown]
# #### 15. Sort the tags DataFrame based on timestamp.

# %%
tags.sort_values(by='timestamp',ascending=False)
# Out:
#         userId  movieId                              tag   timestamp  \
# 339178  102853   115149                    russian mafia  1427771352
# 158780   46072     6058                      premonition  1427760764
# 158763   46072     3409                      premonition  1427760726
# 288375   87797      215                           Vienna  1427755801
# 290535   88044   106782                        profanity  1427754096
# 290527   88044   106782                            crime  1427753921
# 290526   88044   106782                           Amoral  1427753913
# 290531   88044   106782                       Jonah Hill  1427753849
# 290530   88044   106782                       inaccurate  1427753806
# 290528   88044   106782  Economically Illiterate Writers  1427753739
# 290533   88044   106782                Left-Wing Writers  1427753621
# 290532   88044   106782             Left-Wing Propaganda  1427753266
# 290529   88044   106782                             ENFP  1427753147
# ...
